# %% [markdown]
# # Assignment 03
#
# # Exploratory Data Analysis (EDA)
#
#
# #### Bring your own Data and write your own code
#
# ![http://www.pratt.edu/tiny_mce/plugins/imagemanager/files/Light_brown_blue22.jpg](http://www.pratt.edu/tiny_mce/plugins/imagemanager/files/Light_brown_blue22.jpg)

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Assignment-03" data-toc-modified-id="Assignment-03-1">Assignment 03</a></span></li><li><span><a href="#Exploratory-Data-Analysis-(EDA)" data-toc-modified-id="Exploratory-Data-Analysis-(EDA)-2">Exploratory Data Analysis (EDA)</a></span><ul class="toc-item"><li><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Bring-your-own-Data-and-write-your-own-code" data-toc-modified-id="Bring-your-own-Data-and-write-your-own-code-2.0.0.1">Bring your own Data and write your own code</a></span></li></ul></li></ul></li></ul></li><li><span><a href="#Exploratory-Data-Analysis-(EDA)" data-toc-modified-id="Exploratory-Data-Analysis-(EDA)-3">Exploratory Data Analysis (EDA)</a></span><ul class="toc-item"><li><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Bring-your-own-Data-and-write-your-own-code" data-toc-modified-id="Bring-your-own-Data-and-write-your-own-code-3.0.0.1">Bring your own Data and write your own code</a></span></li></ul></li></ul></li><li><span><a href="#Instructions" data-toc-modified-id="Instructions-3.1">Instructions</a></span></li><li><span><a href="#Due-Date-Monday-2020/04/13" data-toc-modified-id="Due-Date-Monday-2020/04/13-3.2">Due Date Monday 2020/04/13</a></span></li></ul></li><li><span><a href="#Import-Libraries" data-toc-modified-id="Import-Libraries-4">Import Libraries</a></span></li><li><span><a href="#1.-Find-some-spatial-Data" data-toc-modified-id="1.-Find-some-spatial-Data-5">1. Find some spatial Data</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Where-does-your-data-come-from?" data-toc-modified-id="Where-does-your-data-come-from?-5.0.1">Where does your data come from?</a></span></li><li><span><a href="#Describe-how-your-data-is-generated." data-toc-modified-id="Describe-how-your-data-is-generated.-5.0.2">Describe how your data is generated.</a></span></li><li><span><a href="#Why-did-you-choose-this-data-file?" data-toc-modified-id="Why-did-you-choose-this-data-file?-5.0.3">Why did you choose this data file?</a></span></li></ul></li></ul></li><li><span><a href="#2.-Load-in-your-Geospatial-Data-as-GeoDataFrame" data-toc-modified-id="2.-Load-in-your-Geospatial-Data-as-GeoDataFrame-6">2. Load in your Geospatial Data as GeoDataFrame</a></span><ul class="toc-item"><li><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Load-your-file-into-a-GeoDataFrame" data-toc-modified-id="Load-your-file-into-a-GeoDataFrame-6.0.0.1">Load your file into a GeoDataFrame</a></span></li><li><span><a href="#Show-the-head()-of-the-DataFrame" data-toc-modified-id="Show-the-head()-of-the-DataFrame-6.0.0.2">Show the <code>head(</code>) of the DataFrame</a></span></li><li><span><a href="#Show-the-tail()-of-the-DataFrame" data-toc-modified-id="Show-the-tail()-of-the-DataFrame-6.0.0.3">Show the <code>tail(</code>) of the DataFrame</a></span></li><li><span><a href="#(Optional)--Do-any-additional-or-other-Data-Exploration-or-Transformation-to-your-data-in-cell(s)-below;" data-toc-modified-id="(Optional)--Do-any-additional-or-other-Data-Exploration-or-Transformation-to-your-data-in-cell(s)-below;-6.0.0.4">(Optional)  Do any additional or other Data Exploration or Transformation to your data in cell(s) below;</a></span></li></ul></li></ul></li></ul></li><li><span><a href="#3.-Exploratory-Data-Analysis-(EDA)-Plots" data-toc-modified-id="3.-Exploratory-Data-Analysis-(EDA)-Plots-7">3. Exploratory Data Analysis (EDA) Plots</a></span><ul class="toc-item"><li><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Plot-the-Distribution-of-one-of-your-data's-columns-in-a-Histogram-Plot-or-some-other-Matplotlib,-Seaborn,-Missingno-plot" data-toc-modified-id="Plot-the-Distribution-of-one-of-your-data's-columns-in-a-Histogram-Plot-or-some-other-Matplotlib,-Seaborn,-Missingno-plot-7.0.0.1">Plot the Distribution of one of your data's columns in a Histogram Plot or some other Matplotlib, Seaborn, Missingno plot</a></span></li><li><span><a href="#(Optional)-Do-any-additional-or-other-Plots-in-cell(s)-below;" data-toc-modified-id="(Optional)-Do-any-additional-or-other-Plots-in-cell(s)-below;-7.0.0.2">(Optional) Do any additional or other Plots in cell(s) below;</a></span></li></ul></li></ul></li></ul></li><li><span><a href="#4.-Map-your-Data" data-toc-modified-id="4.-Map-your-Data-8">4. Map your Data</a></span><ul class="toc-item"><li><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Create-GeoDataFrame-Map--.plot()-to-see-our-the-spatial-distribution-of-your-data" data-toc-modified-id="Create-GeoDataFrame-Map--.plot()-to-see-our-the-spatial-distribution-of-your-data-8.0.0.1">Create GeoDataFrame Map  <code>.plot()</code> to see our the spatial distribution of your data</a></span></li><li><span><a href="#(Optional)-Do-any-additional-or-other-Maps-in-cell(s)-below;" data-toc-modified-id="(Optional)-Do-any-additional-or-other-Maps-in-cell(s)-below;-8.0.0.2">(Optional) Do any additional or other Maps in cell(s) below;</a></span></li></ul></li></ul></li></ul></li><li><span><a href="#5.-Highlight-any-interesting-findings" data-toc-modified-id="5.-Highlight-any-interesting-findings-9">5. Highlight any interesting findings</a></span></li><li><span><a href="#6.-Present" data-toc-modified-id="6.-Present-10">6. Present</a></span></li></ul></div>

# %% [markdown]
# # Exploratory Data Analysis (EDA)
#
#
# #### Bring your own Data and write your own code
#
# ---
#
#
# ## Instructions
#
#
# Assignment 03 is fairly open-ended and you can do as much or as little as you like. However, you are **required** to do the following;
#
#
# 1. **Find** a geospatial data file
# 2. Read it in as a **GeoDataFrame**
# 3. **Perform** some **Exploratory Data Analysis** (EDA) by **creating some plots that describe your data**
#   - Perhaps plot a Histogram
#   - Perhaps plot a Bar Chart
#   - Perhaps plot a Scatterplot of two variables
# 4. **Plot a map**
#   - Required: A map title
#   - A larger than default `figsize`.
# 5. **Highlight any interesting findings**
#
# 6. **Present** your Exploratory Data Analysis to the class **Monday 2020/04/13**
#   - Required: Present your Notebook to the class - **5-7 minute presentation in class on Monday 2020/04/13**.
#   - No need for Powerpoint or Slides, **you'll present your Notebook**.
#
#
# **Optional**:
# You may choose to do the following tasks for more practice and deeper insights. I recommended doing one of the following;
#
# * Perform some Geoprocessing (Reprojection, Buffer, Centroid, Overlay (Intersection, etc)) and plot a map.
# * Thematically style your data map, i.e. a Choropleth, Graduate Symbol, etc.
#
# If you need some inspiration for data sources try:
#
# * [NYC Open Data](https://opendata.cityofnewyork.us/)
# * [NYS Open Data](https://data.ny.gov/)
# * [US Data.gov](https://www.data.gov/)
#
# Otherwise **bring your own data**. **Note:** if your data is medical or health patient data or business data where security is an issue, **DO NOT USE BUSINESS SENSITIVE OR Personally Identifiable Information (PII) data**. If you are not sure, ask me in Slack via a Direct Message.
#
# ## Due Date Monday 2020/04/13
#
# This Assignment 03 is **due Monday 2020/04/13**.
#
# You will be **presenting your Notebook to the class - 5-7 minute presentation in class on Monday 2020/04/13**.  No need for Powerpoint or Slides, you'll present your Notebook.

# %% [markdown]
# # Import Libraries
# The libraries required for this assignment are imported for you below.

# %%
import pandas as pd
import geopandas as gpd 
import numpy as np
import matplotlib.pyplot as plt

# add any additional libraries you need here

# %%
# %matplotlib inline
# run this cell

# %% [markdown]
# # 1. Find some spatial Data
#
# Add some text and links in the sections below.
#
# **IMPORTANT**: If your data file or any component files is greater than 50 MB - please talk to me about `.gitignore`-ing your data before you commit, push your notebook up to GitHub.

# %% [markdown]
# ### Where does your data come from?
#
# * **Data Name**: Electric Vehicle Charging Stations in New York.
# * **Data Source Name**: U.S. Dept. of Energy National Renewable Energy Laboratory / New York State Energy Research & Development Authority (NYSERDA)
# * **Data Source Link**: https://data.ny.gov/Energy-Environment/Electric-Vehicle-Charging-Stations-in-New-York/7rrd-248n

# %% [markdown]
# ### Describe how your data is generated.
#
# Database of alternative (electric) fuel station locations in New York State

# %% [markdown]
# ### Why did you choose this data file?
#
# I initially wanted to use COVID-19 testing sites/numbers data, but its geodata was not available (no long & lat).  So I was data browsing at NYS Open Data and found Electric Vehicle Charging Stations in New York geodata.

# %% [markdown]
# # 2. Load in your Geospatial Data as GeoDataFrame

# %% [markdown]
# #### Load your file into a GeoDataFrame
# See **Lesson 03 GeoPandas section** for reference.
#
# You're being asking to load the GeoDataFrame as a variable named `gdf`.
#
# ```python
#
# gdf = # "read" the file
#
# ```

# %%
### your code here
elec_charge_station_url='https://data.ny.gov/api/views/7rrd-248n/rows.csv?accessType=DOWNLOAD&sorting=true'

# %%
df = pd.read_csv(elec_charge_station_url)

# %% [markdown]
# #### Show the `head(`) of the DataFrame

# %%
### your code here
df.head()
# Out:
#   Fuel Type Code                           Station Name      Street Address  \
# 0           ELEC  Court Square Municipal Parking Garage     45 Court Square
# 1           ELEC                              ScottTech        336 Court St
# 2           ELEC                  Walmart 1949 Fredonia  10401 Bennett Road
# 3           ELEC                             NORTH WOOD       700 Warren Rd
# 4           ELEC                     Glen Avenue Suites          6 Glen Ave
#
#                              Intersection Directions         City State  \
# 0  Located between Court Square East and Court Sq...       Queens    NY
# 1                                                NaN   Binghamton    NY
# 2                                                NaN     Fredonia    NY
# 3                                       STATION 1; -       Ithaca    NY
# 4                                                NaN  Cooperstown    NY
#
#      ZIP  Plus4 Station Phone Status Code  ...   Latitude  Longitude  \
# 0  11101    NaN  866-816-7584           E  ...  40.745358 -73.942642
# 1  13904    NaN  315-214-6065           E  ...  42.103472 -75.892293
# 2  14063    NaN  833-632-2778           E  ...  42.453787 -79.311176
# 3  14850    NaN  888-758-4389           E  ...  42.486806 -76.470601
# 4  13326    NaN  607-547-5054           E  ...  42.698540 -74.931170
#
#   Date Last Confirmed      ID           Updated At  Owner Type Code  \
# 0          01/13/2020   65290  2020-03-30 21:27:46               LG
# 1          04/08/2019   67753  2020-01-21 18:34:38                P
# 2          04/13/2020  121723  2020-04-13 10:18:26              NaN
# 3          04/13/2020  123048  2020-04-13 09:18:21              NaN
# 4          03/03/2020  131661  2020-03-03 21:13:47                P
#
#    Federal Agency ID  Federal Agency Name   Open Date  EV Connector Types
# 0                NaN                  NaN  12/29/2014               J1772
# 1                NaN                  NaN  04/01/2015               J1772
# 2                NaN                  NaN         NaN  CHADEMO J1772COMBO
# 3                NaN                  NaN         NaN               J1772
# 4                NaN                  NaN  07/15/2019               J1772
#
# [5 rows x 31 columns]

# %% [markdown]
# #### Show the `tail(`) of the DataFrame

# %%
### your code here
df.tail()
# Out:
#      Fuel Type Code                                       Station Name  \
# 1659           ELEC           Clemson Bros Brewery - Tesla Destination
# 1660           ELEC                                      Lebrun Nissan
# 1661           ELEC  GGMC Parking 350 W 43rd Street Garage - Tesla ...
# 1662           ELEC                          Essex County - Courthouse
# 1663           ELEC      iPark NYC 246 E 45 Street - Tesla Destination
#
#         Street Address Intersection Directions           City State    ZIP  \
# 1659     22 Cottage St                     NaN     Middletown    NY  10940
# 1660     396 Grant Ave                     NaN         Auburn    NY  13021
# 1661  350 West 43rd St                     NaN       New York    NY  10036
# 1662     7553 Court St                     NaN  Elizabethtown    NY  12932
# 1663    246  E 45th St                     NaN       New York    NY  10017
#
#       Plus4               Station Phone Status Code  ...   Latitude  \
# 1659    NaN  845-775-4638  877-798-3752           E  ...  41.446952
# 1660    NaN                315-253-7700           E  ...  42.966894
# 1661    NaN  212-315-1646  877-798-3752           E  ...  40.758503
# 1662    NaN                518-873-3320           E  ...  44.214426
# 1663    NaN  212-599-8658  877-798-3752           E  ...  40.751676
#
#       Longitude Date Last Confirmed      ID           Updated At  \
# 1659 -74.415608          09/30/2019  114975  2020-03-02 20:14:21
# 1660 -76.535879          09/09/2019   44321  2020-01-21 18:34:38
# 1661 -73.991285          09/30/2019  115109  2020-03-02 20:14:21
# 1662 -73.594677          03/03/2020  142583  2020-03-03 21:13:47
# 1663 -73.971144          09/30/2019  115067  2020-03-02 20:14:21
#
#       Owner Type Code  Federal Agency ID  Federal Agency Name   Open Date  \
# 1659                P                NaN                  NaN  11/01/2018
# 1660                P                NaN                  NaN  11/30/2011
# 1661                P                NaN                  NaN  01/01/2016
# 1662               LG                NaN                  NaN  06/01/2019
# 1663                P                NaN                  NaN  06/01/2016
#
#      EV Connector Types
# 1659              TESLA
# 1660              J1772
# 1661        J1772 TESLA
# 1662              J1772
# 1663        J1772 TESLA
#
# [5 rows x 31 columns]

# %% [markdown]
# #### (Optional)  Do any additional or other Data Exploration or Transformation to your data in cell(s) below;

# %%
### your optional code here
df.shape
# Out:
# (1664, 31)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1664 entries, 0 to 1663
# Data columns (total 31 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Fuel Type Code           1664 non-null   object
#  1   Station Name             1664 non-null   object
#  2   Street Address           1664 non-null   object
#  3   Intersection Directions  764 non-null    object
#  4   City                     1664 non-null   object
#  5   State                    1664 non-null   object
#  6   ZIP                      1664 non-null   int64
#  7   Plus4                    0 non-null      float64
#  8   Station Phone            1652 non-null   object
#  9   Status Code              1664 non-null   object
#  10  Expected Date            0 non-null      float64
#  11  Groups With Access Code  1664 non-null   object
#  12  Access Days Time         1664 non-null   object
#  13  Cards Accepted           45 non-null     object
#  14  EV Level1 EVSE Num       11 non-null     float64
#  15  EV Level2 EVSE Num       1560 non-null   float64
#  16  EV DC Fast Count         130 non-null    float64
#  17  EV Other Info            0 non-null      float64
#  18  EV Network               1664 non-null   object
#  19  EV Network Web           1531 non-null   object
#  20  Geocode Status           1664 non-null   object
#  21  Latitude                 1664 non-null   float64
#  22  Longitude                1664 non-null   float64
#  23  Date Last Confirmed      1662 non-null   object
#  24  ID                       1664 non-null   int64
#  25  Updated At               1664 non-null   object
#  26  Owner Type Code          838 non-null    object
#  27  Federal Agency ID        1 non-null      float64
#  28  Federal Agency Name      1 non-null      object
#  29  Open Date                838 non-null    object
#  30  EV Connector Types       1664 non-null   object
# dtypes: float64(9), int64(2), object(20)
# memory usage: 403.1+ KB

# %% [markdown]
# ## Problem 1: Need a counter
#
# ### Fix: Create a column 'Count' and its value as 1

# %%
df['Count'] = 1
# df['City Title'] = df['City'].str.title()  # 'clifton park', 'new york', 'rochester' not capitalized
# df.head()

# %% [markdown]
# ## Problem2: Some neighborhood names (in Bronx/Queens/Staten Island) are used as a City name instead.
#
# ### Fix: Geo Spatial Join with Borough Data
#
# In order to do a Spatial Join, I first have to convert the Charing Station Data Frame to a GeoDataFrame.
#
# * First, add a 'Geometry' column -> Point(Longitude, Latitude)
# * Then convert df to gdf

# %%
from shapely.geometry import Point
from geopandas import GeoDataFrame

# %%
df['Geometry']=df.apply(lambda row:Point(row['Longitude'], row['Latitude']), axis=1)

df.head()
# Out:
#   Fuel Type Code                           Station Name      Street Address  \
# 0           ELEC  Court Square Municipal Parking Garage     45 Court Square
# 1           ELEC                              ScottTech        336 Court St
# 2           ELEC                  Walmart 1949 Fredonia  10401 Bennett Road
# 3           ELEC                             NORTH WOOD       700 Warren Rd
# 4           ELEC                     Glen Avenue Suites          6 Glen Ave
#
#                              Intersection Directions         City State  \
# 0  Located between Court Square East and Court Sq...       Queens    NY
# 1                                                NaN   Binghamton    NY
# 2                                                NaN     Fredonia    NY
# 3                                       STATION 1; -       Ithaca    NY
# 4                                                NaN  Cooperstown    NY
#
#      ZIP  Plus4 Station Phone Status Code  ...  Date Last Confirmed      ID  \
# 0  11101    NaN  866-816-7584           E  ...           01/13/2020   65290
# 1  13904    NaN  315-214-6065           E  ...           04/08/2019   67753
# 2  14063    NaN  833-632-2778           E  ...           04/13/2020  121723
# 3  14850    NaN  888-758-4389           E  ...           04/13/2020  123048
# 4  13326    NaN  607-547-5054           E  ...           03/03/2020  131661
#
#             Updated At Owner Type Code  Federal Agency ID  \
# 0  2020-03-30 21:27:46              LG                NaN
# 1  2020-01-21 18:34:38               P                NaN
# 2  2020-04-13 10:18:26             NaN                NaN
# 3  2020-04-13 09:18:21             NaN                NaN
# 4  2020-03-03 21:13:47               P                NaN
#
#    Federal Agency Name   Open Date  EV Connector Types Count  \
# 0                  NaN  12/29/2014               J1772     1
# 1                  NaN  04/01/2015               J1772     1
# 2                  NaN         NaN  CHADEMO J1772COMBO     1
# 3                  NaN         NaN               J1772     1
# 4                  NaN  07/15/2019               J1772     1
#
#                                Geometry
# 0  POINT (-73.94264200000001 40.745358)
# 1  POINT (-75.89229300000001 42.103472)
# 2          POINT (-79.311176 42.453787)
# 3          POINT (-76.470601 42.486806)
# 4   POINT (-74.93116999999999 42.69854)
#
# [5 rows x 33 columns]

# %%
gdf = GeoDataFrame(df, geometry = 'Geometry')

gdf.plot();

# %% [markdown]
# ## Importing NYC Borough Geodata

# %%
boro_geojson_url = 'https://data.cityofnewyork.us/api/geospatial/tqmj-j8zm?method=export&format=GeoJSON'

# %%
boro_gdf = gpd.read_file(boro_geojson_url)

# %%
boro_gdf.to_crs(epsg=2263, inplace=True)

boro_gdf
# Out:
#   boro_code      boro_name     shape_area     shape_leng  \
# 0         2          Bronx  1186612478.27  462958.187578
# 1         5  Staten Island  1623757282.78     325956.009
# 2         3       Brooklyn  1937593022.64  738745.842115
# 3         4         Queens  3045878293.21  904188.424488
# 4         1      Manhattan  636602658.887  361212.476098
#
#                                             geometry
# 0  MULTIPOLYGON (((1012821.806 229228.265, 101278...
# 1  MULTIPOLYGON (((970217.022 145643.332, 970227....
# 2  MULTIPOLYGON (((1021176.479 151374.797, 102100...
# 3  MULTIPOLYGON (((1029606.077 156073.814, 102957...
# 4  MULTIPOLYGON (((981219.056 188655.316, 980940....

# %%
boro_gdf.plot();

# %% [markdown]
# ## Perform Spatial Join

# %%
# Spatial Join

new_gdf = gpd.sjoin(
    gdf,
    boro_gdf[['boro_name', 'geometry']].to_crs(epsg=4326),  # how come epsg=2263 doesn't work?
    how='left',
)

new_gdf.head()
# Out:
# C:\Users\dun4g\anaconda3\envs\GIS\lib\site-packages\geopandas\tools\sjoin.py:61: UserWarning: CRS of frames being joined does not match!(None != {'init': 'epsg:4326', 'no_defs': True})
#   "(%s != %s)" % (left_df.crs, right_df.crs)
#   Fuel Type Code                           Station Name      Street Address  \
# 0           ELEC  Court Square Municipal Parking Garage     45 Court Square
# 1           ELEC                              ScottTech        336 Court St
# 2           ELEC                  Walmart 1949 Fredonia  10401 Bennett Road
# 3           ELEC                             NORTH WOOD       700 Warren Rd
# 4           ELEC                     Glen Avenue Suites          6 Glen Ave
#
#                              Intersection Directions         City State  \
# 0  Located between Court Square East and Court Sq...       Queens    NY
# 1                                                NaN   Binghamton    NY
# 2                                                NaN     Fredonia    NY
# 3                                       STATION 1; -       Ithaca    NY
# 4                                                NaN  Cooperstown    NY
#
#      ZIP  Plus4 Station Phone Status Code  ...           Updated At  \
# 0  11101    NaN  866-816-7584           E  ...  2020-03-30 21:27:46
# 1  13904    NaN  315-214-6065           E  ...  2020-01-21 18:34:38
# 2  14063    NaN  833-632-2778           E  ...  2020-04-13 10:18:26
# 3  14850    NaN  888-758-4389           E  ...  2020-04-13 09:18:21
# 4  13326    NaN  607-547-5054           E  ...  2020-03-03 21:13:47
#
#   Owner Type Code Federal Agency ID Federal Agency Name   Open Date  \
# 0              LG               NaN                 NaN  12/29/2014
# 1               P               NaN                 NaN  04/01/2015
# 2             NaN               NaN                 NaN         NaN
# 3             NaN               NaN                 NaN         NaN
# 4               P               NaN                 NaN  07/15/2019
#
#    EV Connector Types  Count                    Geometry index_right boro_name
# 0               J1772      1  POINT (-73.94264 40.74536)         3.0    Queens
# 1               J1772      1  POINT (-75.89229 42.10347)         NaN       NaN
# 2  CHADEMO J1772COMBO      1  POINT (-79.31118 42.45379)         NaN       NaN
# 3               J1772      1  POINT (-76.47060 42.48681)         NaN       NaN
# 4               J1772      1  POINT (-74.93117 42.69854)         NaN       NaN
#
# [5 rows x 35 columns]

# %%
new_gdf.shape
# Out:
# (1664, 35)

# %%
new_gdf.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# Int64Index: 1664 entries, 0 to 1663
# Data columns (total 35 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Fuel Type Code           1664 non-null   object
#  1   Station Name             1664 non-null   object
#  2   Street Address           1664 non-null   object
#  3   Intersection Directions  764 non-null    object
#  4   City                     1664 non-null   object
#  5   State                    1664 non-null   object
#  6   ZIP                      1664 non-null   int64
#  7   Plus4                    0 non-null      float64
#  8   Station Phone            1652 non-null   object
#  9   Status Code              1664 non-null   object
#  10  Expected Date            0 non-null      float64
#  11  Groups With Access Code  1664 non-null   object
#  12  Access Days Time         1664 non-null   object
#  13  Cards Accepted           45 non-null     object
#  14  EV Level1 EVSE Num       11 non-null     float64
#  15  EV Level2 EVSE Num       1560 non-null   float64
#  16  EV DC Fast Count         130 non-null    float64
#  17  EV Other Info            0 non-null      float64
#  18  EV Network               1664 non-null   object
#  19  EV Network Web           1531 non-null   object
#  20  Geocode Status           1664 non-null   object
#  21  Latitude                 1664 non-null   float64
#  22  Longitude                1664 non-null   float64
#  23  Date Last Confirmed      1662 non-null   object
#  24  ID                       1664 non-null   int64
#  25  Updated At               1664 non-null   object
#  26  Owner Type Code          838 non-null    object
#  27  Federal Agency ID        1 non-null      float64
#  28  Federal Agency Name      1 non-null      object
#  29  Open Date                838 non-null    object
#  30  EV Connector Types       1664 non-null   object
#  31  Count                    1664 non-null   int64
#  32  Geometry                 1664 non-null   geometry
#  33  index_right              498 non-null    float64
#  34  boro_name                498 non-null    object
# dtypes: float64(10), geometry(1), int64(3), object(21)
# memory usage: 468.0+ KB

# %%
# checking to see if 'Astoria' has boro_name 'Queens'
new_gdf[new_gdf['City'] == 'Astoria']
# Out:
#     Fuel Type Code                                       Station Name  \
# 150           ELEC                 19-80 Steinway - Tesla Destination
# 208           ELEC  Sylvan Parking 23-25 31st St, Astoria - Tesla ...
# 448           ELEC         ProPark 29-10 Broadway - Tesla Destination
# 732           ELEC      PV Parking 34-11 Steinway - Tesla Destination
# 744           ELEC        Astoria Central Parking - Tesla Destination
#
#         Street Address Intersection Directions     City State    ZIP  Plus4  \
# 150   1980 Steinway St                     NaN  Astoria    NY  11105    NaN
# 208      23-25 31st St                     NaN  Astoria    NY  11105    NaN
# 448     29-10 Broadway                     NaN  Astoria    NY  11106    NaN
# 732  34-11 Steinway St                     NaN  Astoria    NY  11101    NaN
# 744      31-57 31st St                     NaN  Astoria    NY  11106    NaN
#
#                   Station Phone Status Code  ...           Updated At  \
# 150  347-697-6733  877-798-3752           E  ...  2020-03-02 20:14:21
# 208  718-204-5005  877-798-3752           E  ...  2020-03-02 20:14:21
# 448  718-728-0460  877-798-3752           E  ...  2020-03-02 20:14:21
# 732  718-609-1200  877-798-3752           E  ...  2020-03-02 20:14:21
# 744  718-489-1654  877-798-3752           E  ...  2020-03-02 20:14:21
#
#     Owner Type Code Federal Agency ID Federal Agency Name   Open Date  \
# 150               P               NaN                 NaN  09/30/2019
# 208               P               NaN                 NaN  09/30/2019
# 448               P               NaN                 NaN  09/30/2019
# 732               P               NaN                 NaN  09/30/2019
# 744               P               NaN                 NaN  11/01/2018
#
#      EV Connector Types  Count                    Geometry index_right  \
# 150               TESLA      1  POINT (-73.90138 40.77694)         3.0
# 208               TESLA      1  POINT (-73.91331 40.77363)         3.0
# 448               TESLA      1  POINT (-73.92699 40.76242)         3.0
# 732               TESLA      1  POINT (-73.92217 40.75551)         3.0
# 744               TESLA      1  POINT (-73.92447 40.76276)         3.0
#
#     boro_name
# 150    Queens
# 208    Queens
# 448    Queens
# 732    Queens
# 744    Queens
#
# [5 rows x 35 columns]

# %%
for idx, row in new_gdf.iterrows():             # If using for row in ned_gdf.iterrows():
    if row['boro_name'] == 'Brooklyn':          # row is a tuple, so can't do row['...']
        new_gdf.at[idx, 'City'] = 'Brooklyn'    # must use the index instead row[0]
                                                # row['City'] = 'Brooklyn' didn't work
    elif row['boro_name'] == 'Bronx':
        new_gdf.at[idx, 'City'] = 'Bronx'
        
    elif row['boro_name'] == 'Manhattan':
        new_gdf.at[idx, 'City'] = 'Manhattan'
        
    elif row['boro_name'] == 'Queens':
        new_gdf.at[idx, 'City'] = 'Queens'
            
    elif row['boro_name'] == 'Staten Island':
        new_gdf.at[idx, 'City'] = 'Staten Island'
        
#     if row[33] == 'Brooklyn':   
#         row[4] = 'Broolyn'          
        
#     elif row[33] == 'Bronx':
#         row[4] = 'Bronx'
        
#     elif row[33] == 'New York':
#         row[4] = 'Manhattan'
        
#     elif row[33] == 'Queens':
#         row[4] = 'Queens'
            
#     elif row[33] == 'Staten Island':
#         row[4] = 'Staten Island'
    
    else:
        continue

# %%
new_gdf
# Out:
#      Fuel Type Code                                       Station Name  \
# 0              ELEC              Court Square Municipal Parking Garage
# 1              ELEC                                          ScottTech
# 2              ELEC                              Walmart 1949 Fredonia
# 3              ELEC                                         NORTH WOOD
# 4              ELEC                                 Glen Avenue Suites
# ...             ...                                                ...
# 1659           ELEC           Clemson Bros Brewery - Tesla Destination
# 1660           ELEC                                      Lebrun Nissan
# 1661           ELEC  GGMC Parking 350 W 43rd Street Garage - Tesla ...
# 1662           ELEC                          Essex County - Courthouse
# 1663           ELEC      iPark NYC 246 E 45 Street - Tesla Destination
#
#           Street Address                            Intersection Directions  \
# 0        45 Court Square  Located between Court Square East and Court Sq...
# 1           336 Court St                                                NaN
# 2     10401 Bennett Road                                                NaN
# 3          700 Warren Rd                                       STATION 1; -
# 4             6 Glen Ave                                                NaN
# ...                  ...                                                ...
# 1659       22 Cottage St                                                NaN
# 1660       396 Grant Ave                                                NaN
# 1661    350 West 43rd St                                                NaN
# 1662       7553 Court St                                                NaN
# 1663      246  E 45th St                                                NaN
#
#                City State    ZIP  Plus4               Station Phone  \
# 0            Queens    NY  11101    NaN                866-816-7584
# 1        Binghamton    NY  13904    NaN                315-214-6065
# 2          Fredonia    NY  14063    NaN                833-632-2778
# 3            Ithaca    NY  14850    NaN                888-758-4389
# 4       Cooperstown    NY  13326    NaN                607-547-5054
# ...             ...   ...    ...    ...                         ...
# 1659     Middletown    NY  10940    NaN  845-775-4638  877-798-3752
# 1660         Auburn    NY  13021    NaN                315-253-7700
# 1661      Manhattan    NY  10036    NaN  212-315-1646  877-798-3752
# 1662  Elizabethtown    NY  12932    NaN                518-873-3320
# 1663      Manhattan    NY  10017    NaN  212-599-8658  877-798-3752
#
#      Status Code  ...           Updated At Owner Type Code Federal Agency ID  \
# 0              E  ...  2020-03-30 21:27:46              LG               NaN
# 1              E  ...  2020-01-21 18:34:38               P               NaN
# 2              E  ...  2020-04-13 10:18:26             NaN               NaN
# 3              E  ...  2020-04-13 09:18:21             NaN               NaN
# 4              E  ...  2020-03-03 21:13:47               P               NaN
# ...          ...  ...                  ...             ...               ...
# 1659           E  ...  2020-03-02 20:14:21               P               NaN
# 1660           E  ...  2020-01-21 18:34:38               P               NaN
# 1661           E  ...  2020-03-02 20:14:21               P               NaN
# 1662           E  ...  2020-03-03 21:13:47              LG               NaN
# 1663           E  ...  2020-03-02 20:14:21               P               NaN
#
#      Federal Agency Name   Open Date  EV Connector Types  Count  \
# 0                    NaN  12/29/2014               J1772      1
# 1                    NaN  04/01/2015               J1772      1
# 2                    NaN         NaN  CHADEMO J1772COMBO      1
# 3                    NaN         NaN               J1772      1
# 4                    NaN  07/15/2019               J1772      1
# ...                  ...         ...                 ...    ...
# 1659                 NaN  11/01/2018               TESLA      1
# 1660                 NaN  11/30/2011               J1772      1
# 1661                 NaN  01/01/2016         J1772 TESLA      1
# 1662                 NaN  06/01/2019               J1772      1
# 1663                 NaN  06/01/2016         J1772 TESLA      1
#
#                         Geometry index_right  boro_name
# 0     POINT (-73.94264 40.74536)         3.0     Queens
# 1     POINT (-75.89229 42.10347)         NaN        NaN
# 2     POINT (-79.31118 42.45379)         NaN        NaN
# 3     POINT (-76.47060 42.48681)         NaN        NaN
# 4     POINT (-74.93117 42.69854)         NaN        NaN
# ...                          ...         ...        ...
# 1659  POINT (-74.41561 41.44695)         NaN        NaN
# 1660  POINT (-76.53588 42.96689)         NaN        NaN
# 1661  POINT (-73.99128 40.75850)         4.0  Manhattan
# 1662  POINT (-73.59468 44.21443)         NaN        NaN
# 1663  POINT (-73.97114 40.75168)         4.0  Manhattan
#
# [1664 rows x 35 columns]

# %%
# checking to see if new_gdf['City'] = 'Astoria' still exists
new_gdf[new_gdf['City']=='Astoria'].shape
# Out:
# (0, 35)

# %%
station_count = new_gdf[['City', 'Count']]

top_10 = station_count.groupby('City', as_index=False) \
                      .sum() \
                      .sort_values(['Count'], ascending=False) \
                      .head(10)
top_10
# Out:
#                  City  Count
# 219         Manhattan    332
# 45           Brooklyn     77
# 293            Queens     64
# 299         Rochester     59
# 1              Albany     45
# 47            Buffalo     42
# 313  Saratoga Springs     33
# 317       Schenectady     23
# 196          Kingston     22
# 184            Ithaca     22

# %%
nyc_stations = new_gdf[                         # You can also use .isin(['New York', ...]) alternatively
    (new_gdf['boro_name'] == 'Manhattan') |     # Why must use Bitwise Operator instead of Logical Operator?
    (new_gdf['boro_name'] == 'Bronx') | 
    (new_gdf['boro_name'] == 'Queens') |        # Queens is weird with its City names (has 'Astoria', 'Flushing', etc.)
    (new_gdf['boro_name'] == 'Brooklyn') |
    (new_gdf['boro_name'] == 'Staten Island')
]
                
nyc_stations.head()
# Out:
#    Fuel Type Code                                       Station Name  \
# 0            ELEC              Court Square Municipal Parking Garage
# 8            ELEC   Icon Parking 1056 5th Avenue - Tesla Destination
# 12           ELEC      Sutton Place North Garage - Tesla Destination
# 15           ELEC       iPark NYC 2234 North 6th - Tesla Destination
# 16           ELEC  Grand Ave Bus Depot & Central Maintenance Faci...
#
#      Street Address                            Intersection Directions  \
# 0   45 Court Square  Located between Court Square East and Court Sq...
# 8      10 E 87th St                                                NaN
# 12    420 E 54th St                                                NaN
# 15  34 North 6th St                                                NaN
# 16   4805 Grand Ave                                                NaN
#
#          City State    ZIP  Plus4               Station Phone Status Code  \
# 0      Queens    NY  11101    NaN                866-816-7584           E
# 8   Manhattan    NY  10028    NaN  212-534-9437  877-798-3752           E
# 12  Manhattan    NY  10022    NaN  212-752-7504  877-798-3752           E
# 15   Brooklyn    NY  11249    NaN  855-472-7569  877-798-3752           E
# 16     Queens    NY  11378    NaN                866-816-7584           E
#
#     ...           Updated At Owner Type Code Federal Agency ID  \
# 0   ...  2020-03-30 21:27:46              LG               NaN
# 8   ...  2020-03-02 20:14:21               P               NaN
# 12  ...  2020-03-02 20:14:21               P               NaN
# 15  ...  2020-03-02 20:14:21               P               NaN
# 16  ...  2020-04-08 12:29:55               P               NaN
#
#    Federal Agency Name   Open Date  EV Connector Types  Count  \
# 0                  NaN  12/29/2014               J1772      1
# 8                  NaN  09/01/2017         J1772 TESLA      1
# 12                 NaN  11/01/2018               TESLA      1
# 15                 NaN  01/01/2016         J1772 TESLA      1
# 16                 NaN  04/01/2019               J1772      1
#
#                       Geometry index_right  boro_name
# 0   POINT (-73.94264 40.74536)         3.0     Queens
# 8   POINT (-73.95948 40.78203)         4.0  Manhattan
# 12  POINT (-73.96353 40.75568)         4.0  Manhattan
# 15  POINT (-73.96293 40.71976)         2.0   Brooklyn
# 16  POINT (-73.92024 40.71743)         3.0     Queens
#
# [5 rows x 35 columns]

# %%
nyc_station_count = nyc_stations[['boro_name', 'Count']]
nyc_rank = nyc_station_count.groupby('boro_name', as_index=False) \
                            .sum() \
                            .sort_values(['Count'], ascending=False) \

nyc_rank
# Out:
#        boro_name  Count
# 2      Manhattan    332
# 1       Brooklyn     77
# 3         Queens     64
# 0          Bronx     17
# 4  Staten Island      8

# %% [markdown]
# # 3. Exploratory Data Analysis (EDA) Plots

# %% [markdown]
# #### Plot the Distribution of one of your data's columns in a Histogram Plot or some other Matplotlib, Seaborn, Missingno plot
# If you have a numerical column, otherwise plot a bar plot to show categorical counts.
#
# * Here's an code example for a bar plot - https://python-graph-gallery.com/1-basic-barplot

# %%
### your code here
plt.figure(figsize=(15, 8))

plt.bar(
    top_10['City'],
    top_10['Count'],
);

# for idx, val in enumerate(top_10):
#     plt.text(
#         x = top_10['City Title'][i],
#         y = top_10['Count'][i],
#         s = str(val)
#     )

plt.title('Electric Vehicle Charging Station Count by City')
# Out:
# Text(0.5, 1.0, 'Electric Vehicle Charging Station Count by City')

# %%
plt.bar(
    nyc_rank['boro_name'],
    nyc_rank['Count'],
);

plt.title('Electric Vehicle Charging Stations in NYC')
# Out:
# Text(0.5, 1.0, 'Electric Vehicle Charging Stations in NYC')

# %% [markdown]
# #### (Optional) Do any additional or other Plots in cell(s) below;

# %%
### your optional code here
import missingno as msno

missing_df = pd.read_csv('data/Electric_Vehicle_Charging_Stations_in_New_York.csv')

# %%
msno.matrix(missing_df);

# %% [markdown]
# # 4. Map your Data
#
# #### Create GeoDataFrame Map  `.plot()` to see our the spatial distribution of your data
#
# For this, please **add argument** `figsize=(10, 10)` inside our `.plot( )` function.
#
# * Add a title to your `plt` as well. _Hint `plt.title(...)`.

# %%
# x = df.Longitude
# y = df.Latitude

# plt.figure(figsize=(15, 10))
# plt.title('Electric Vehicle Charging Stations in New York')
# plt.scatter(x, y)
# plt.show()

# %%
ny_counties_url = 'https://raw.githubusercontent.com/codeforamerica/click_that_hood/master/public/data/new-york-counties.geojson'
ny_counties = gpd.read_file(ny_counties_url)
ny_counties
# Out:
#            geoid                name  \
# 0   05000US36041     Hamilton County
# 1   05000US36017     Chenango County
# 2   05000US36051   Livingston County
# 3   05000US36097     Schuyler County
# 4   05000US36095    Schoharie County
# ..           ...                 ...
# 57  05000US36085     Richmond County
# 58  05000US36009  Cattaraugus County
# 59  05000US36043     Herkimer County
# 60  05000US36063      Niagara County
# 61  05000US36079       Putnam County
#
#                                              geometry
# 0   MULTIPOLYGON (((-74.82011 43.81851, -74.85417 ...
# 1   MULTIPOLYGON (((-75.40346 42.50870, -75.40019 ...
# 2   MULTIPOLYGON (((-78.06088 42.53636, -78.05929 ...
# 3   MULTIPOLYGON (((-77.10487 42.38929, -77.10720 ...
# 4   MULTIPOLYGON (((-74.33880 42.78224, -74.28945 ...
# ..                                                ...
# 57  MULTIPOLYGON (((-74.24927 40.54492, -74.24742 ...
# 58  MULTIPOLYGON (((-79.06071 42.34792, -79.06078 ...
# 59  MULTIPOLYGON (((-75.20736 42.94057, -75.21911 ...
# 60  MULTIPOLYGON (((-79.05427 43.21844, -79.05286 ...
# 61  MULTIPOLYGON (((-73.83836 41.49813, -73.69266 ...
#
# [62 rows x 3 columns]

# %%
### your code here

fig, ax = plt.subplots(figsize=(12, 12))

ny_counties.plot(
    ax=ax,
    facecolor='lightgrey',
)

df.plot(
    ax=ax,
    title = 'Electric Vehicle Charging Stations in New York',
    x = 'Longitude',
    y = 'Latitude',
    kind = 'scatter',
)

plt.show()

# %% [markdown]
# #### (Optional) Do any additional or other Maps in cell(s) below;

# %%
### your optional code here
import folium
from folium.plugins import MarkerCluster

m = folium.Map(
    location=[
        df['Latitude'].mean(),
        df['Longitude'].mean(),
    ],
    zoom_start = 6,
)

mc = MarkerCluster()

for i, row in df.iterrows():  #for row in df.itertuples():
    mc.add_child(
        folium.Marker(
            location=[row.Latitude, row.Longitude],
            popup=row['Station Name']  # popup=row.ZIP
        )
    )
    
    m.add_child(mc)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
m.save('index.html')

# %% [markdown]
# ## You can see a version of the map here:
#
# https://katkim0307.github.io/pratt-savi-810-2020-03-assignment_03/

# %% [markdown]
# # 5. Highlight any interesting findings
#
# If there's any interesting summary statistics or findings or plots in a few key bullet points below, list some interesting notes about your data.
#
# Examples
# * My data is not normally distributed.
# * Over 50% of my values for column X are missing values.
# * I have suspicious outliers in my data
# * There appears to be some Geographic Distribution or pattern in your data.
# * Variable X appears to be correlated with Variable Y (statistical test(s) not required).
#
#
# #### 'City' column needed a major fix.
#
# #### There are 6 columns with no values - Plus4, Expected Date, EV Level1 EVSE Num (Standard 110V Outlet), EV Other Info, Federal Agency ID, and Federal Agency Name.

# %% [markdown]
# # 6. Present
#
# This will be done in class, you'll need to present your Jupyter Notebook in class.
#
# **Present** your Exploratory Data Analysis to the class Monday 2020/04/13
#   - Required: Present your Notebook to the class - 5-7 minute presentation in class on Monday 2020/04/13.
#   - No need for Powerpoint or Slides, you'll present your Notebook.
